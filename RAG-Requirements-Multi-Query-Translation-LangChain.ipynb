# %%
'''
RAG - Job Requirements Validation Against a Resume

Instead of a simple question, this sample program validates if the resume of a candidate 
can satisfy the necessary job requirements.

1. The logic starts with Multi-Query translation of each Job Requirement to multiple sub-questions.
2. The logic queries each sub-question against the resume and aggregates 
all the answers from sub-questions as the aggregated context. (similar to RAG Decomposition) 
3. The final logic queries the aggregated context with the requirement and provides a summary to 
identify if this candidate meets this job requirements. 


Input arguments to the step_to_step_fusion are
1. Template: how to generate the sub-questions from a requirement
2. Template2: How to generate the summary of each requirement
3. Requirements: The requirement list
4. Resume: The resume of a candidate. 

'''

import os
from dotenv import load_dotenv
load_dotenv()

#if (GCP_PROJECT_ID == None): print ("Not set")
OPENAI_API_KEY = os.getenv('OPENAI_API_KEY')
LANGCHAIN_API_KEY = os.getenv('LANGCHAIN_API_KEY')
os.environ['LANGCHAIN_TRACING_V2'] = 'false'  #true for trace
os.environ['LANGCHAIN_ENDPOINT'] = 'https://api.smith.langchain.com'
os.environ["LANGCHAIN_PROJECT"] = "RAG - Multi-Query-Translation"

# %%
#Without using the Chain/Pipeline but same processes

from langchain import hub
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.text_splitter import CharacterTextSplitter
from langchain_community.document_loaders import WebBaseLoader
from langchain_community.vectorstores import Chroma
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough
from langchain_openai import ChatOpenAI, OpenAIEmbeddings
from langchain.load import dumps, loads
from PyPDF2 import PdfReader
from langchain.prompts import ChatPromptTemplate
#Using CharaterTextSplitter maybe have better results than RecursiveCharacterTextSplitter
#text_splitter = RecursiveCharacterTextSplitter(chunk_size=200, chunk_overlap=40)
text_splitter = CharacterTextSplitter()
#keep the default separator ('\n\n') is better than separator="\n"

def extract_pdf_text(file_path):
    pdf_file = PdfReader(file_path)
    text_data = ''
    for pg in pdf_file.pages:
        text_data += pg.extract_text()
    return text_data


def get_unique_union(documents: list[list]):
    """ Unique union of retrieved docs """
    # Flatten list of lists, and convert each Document to string
    flattened_docs = [dumps(doc) for sublist in documents for doc in sublist]
    # Get unique documents
    unique_docs = list(set(flattened_docs))
    # Return
    return [loads(doc) for doc in unique_docs]

    
def step_by_step_query(template, template2, requirements, resume):
    from langchain_core.output_parsers import CommaSeparatedListOutputParser
    #question = "List all the companies Sam have worked for, please also list the year he worked for those companies"
# Multi Query: Different Perspectives
 
    pdf_text = extract_pdf_text(resume)
    pdf_texts = text_splitter.split_text(pdf_text)
    split_docs = text_splitter.create_documents(pdf_texts)
    ''' Don't use OpenAIEmbeddings
    client = OpenAI()
    embedding_repsonse = client.embeddings.create(input=sentences, 
                                      model="text-embedding-3-large")
     '''
    
    vectorstore = Chroma.from_documents(documents=split_docs, 
                                        embedding=OpenAIEmbeddings(model="text-embedding-3-small"))
    retriever = vectorstore.as_retriever(search_kwargs={"k": 4}, max_tokens_limit=10000)
    
    requirements_list = requirements.split('\n\n\n\n')
    print (requirements_list)
    prompt_perspectives = ChatPromptTemplate.from_template(template)
    for requirement in requirements_list:
        #print ("internal_loop...", requirement)
        prompt_perspectives_output =  prompt_perspectives.invoke(requirement)
        #print("Output after prompt_perspectives:", prompt_perspectives_output)

        chat_openai_output = ChatOpenAI(temperature=0)(prompt_perspectives_output)
        ##print("Output after ChatOpenAI:", chat_openai_output)
        #output_parser = CommaSeparatedListOutputParser()
        parser_output = StrOutputParser().invoke(chat_openai_output)
        #print("output after StrOutputParser:", parser_output)
        #str_output_parser_output = output_parser(chat_openai_output)
        #print("Output after StrOutputParser:", str_output_parser_output)
        generate_queries= (lambda x: x.split("\n"))(parser_output)

        #print ("gen...", generate_queries)

        #retrieval_chain = generate_queries | retriever.map() | get_unique_union
 
        #docs = retrieval_chain.invoke({"question":question})

        retriever_output = retriever.map().invoke(generate_queries)
        get_union_doc_output = get_unique_union(retriever_output)

        #print("output after get_unique_union", get_union_doc_output[0])

        #docs = retrieval_chain.invoke({"question":question})
        #docs = get_union_doc_output

        #print("output after retriever map()", retriever_output)
        internal_loop (get_union_doc_output, generate_queries, template2, requirement, resume)
        
        
def internal_loop (get_union_doc_output, generate_queries, template2, requirement, resume):

    prompt = ChatPromptTemplate.from_template(template2)

    llm = ChatOpenAI(temperature=0)
    answers_pair = ""
    for question in generate_queries:
        #print("question... ", question)
        prompt_outputf =  prompt.invoke({"context": get_union_doc_output[0], 
                                        "question": question})
        #print("output from prompt again", prompt_outputf)
        llm_output = llm(prompt_outputf)
        subquestion_summary= StrOutputParser().invoke(llm_output)
        #print ("sub_summary...", subquestion_summary)  
        #based on decomposition we collect results of all subquestions  
        answers_pair = answers_pair + subquestion_summary
    
    #Final Logic Step (3)
    templatef = """Here is a set of subqestion and answer pairs:
    
    {answers_pair}
    Use the subquestion and answer pairs above to summary the similarity, in precetage, 
    if the candidate can satisfy this requirements: 
    {requirement}"""
    
    promptf = ChatPromptTemplate.from_template(templatef)
    final_prompt = promptf.invoke({"answers_pair": answers_pair, "requirement": requirement})
    final_answers = llm(final_prompt)
    print("\n\n\nRequirement....", requirement)
    print ("\nValidation Summary ...", final_answers)

# %%
resume='.\docs\samcyangResume_Gen123.pdf'

#Requirements are gathered from a job postion on job board.
requirements="""Develop and coordinate logistics CDRLs.\n\n\n\n
Must have experience with LORA, SERD, LMI and/or spare analysis\n\n\n\n
Must have experience with business rules, TMCR, IETM and/or CSDB\n\n\n\n
Must have experience with US military program office is desired\n\n\n\n
Must have Government proposal experience is desired\n\n\n\n
Must be able to obtain and hold a US secret security clearance\n\n\n\n
Have Experience manage all phases of the program from conceptualization through completion, including acquisition, planning, and managing technical performance to ensure quality, business, and financial objectives are attained.\n\n\n\n
Participate with engineering to establish design concepts, criteria, and engineering efforts for product research, development, testing, and integration.\n\n\n\n
Interact with internal and external representatives at various levels concerning resolution of technical and scheduling issues. Act as primary contact for Logistics/Sustainment program issues. \n\n\n\n
Influence, and coordinate the preparation of proposals, business plans, proposal work statements and specifications, operating budgets, and financial terms/conditions of contract(s). Influence contract acquisitions, negotiations, and modifications.\n\n\n\n
"""

template = """
You are an AI language model assistant. Your task is to tell me how a
resume is closely matching (in percentage) to the requirements:  

{requirements} 

given by the user. In order to help to better validate the similarity between
the requirement and candidate resume, this task, you can generate 2 sub-questions 
from each given requirement.  

By generating multiple perspectives on the user question, your goal is to help
the user overcome some of the limitations of the distance-based similarity search. 

Also, please provide recommendations if this candidate can meet the requirement 
before moving into next stage
"""


template2 = """Your task is to identify the similarity of a resume to the 
job requirement: {question}.  Based on the requirement, please rank the 
similarity, in percentage, against the context listed below, and also provide
a short summary with recommendations. 

{context}.  

Please note, if a technical keyword listed in the requirement can't be identified in 
the context above then, the similarity will be low in percentage, such as 0%, 

"""




step_by_step_query(template, template2, requirements, resume)
# Out:
# ['Develop and coordinate logistics CDRLs.', '\nMust have experience with LORA, SERD, LMI and/or spare analysis', '\nMust have experience with business rules, TMCR, IETM and/or CSDB', '\nMust have experience with US military program office is desired', '\nMust have Government proposal experience is desired', '\nMust be able to obtain and hold a US secret security clearance', '\nHave Experience manage all phases of the program from conceptualization through completion, including acquisition, planning, and managing technical performance to ensure quality, business, and financial objectives are attained.', '\nParticipate with engineering to establish design concepts, criteria, and engineering efforts for product research, development, testing, and integration.', '\nInteract with internal and external representatives at various levels concerning resolution of technical and scheduling issues. Act as primary contact for Logistics/Sustainment program issues. ', '\nInfluence, and coordinate the preparation of proposals, business plans, proposal work statements and specifications, operating budgets, and financial terms/conditions of contract(s). Influence contract acquisitions, negotiations, and modifications.', '\n']
#
#
#
# Requirement.... Develop and coordinate logistics CDRLs.
#
# Validation Summary ... content="Based on the subquestion and answer pairs provided, the candidate's resume does not specifically mention experience in developing and coordinating logistics CDRLs. Therefore, the similarity percentage would be low, around 10-20%. The candidate's experience is primarily focused on program management, product development, and technical project management, which may not directly align with the logistics coordination aspect of CDRLs. \n\nRecommendation: While the candidate's extensive experience in program management and technical project management is valuable, it would be beneficial for them to highlight any specific experience or skills related to logistics coordination in CDRLs in order to better align with the job requirement. Additionally, the candidate may consider gaining more experience or training in logistics coordination to enhance their qualifications for roles that require this specific skill set." response_metadata={'token_usage': {'completion_tokens': 155, 'prompt_tokens': 1487, 'total_tokens': 1642}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None} id='run-b613c983-888f-42ac-89d6-49a61d114bc7-0' usage_metadata={'input_tokens': 1487, 'output_tokens': 155, 'total_tokens': 1642}
#
#
#
# Requirement....
# Must have experience with LORA, SERD, LMI and/or spare analysis
#
# Validation Summary ... content="Based on the subquestion and answer pairs provided, the candidate's resume shows a low similarity percentage of around 0% for experience with LORA, SERD, LMI, and spare analysis. The resume primarily focuses on program management, software development, and engineering in consumer electronics, robotics, and software systems, with no specific mention of experience in the required areas. Therefore, the candidate may not fully satisfy the requirements for experience with LORA, SERD, LMI, and spare analysis based on the information provided." response_metadata={'token_usage': {'completion_tokens': 105, 'prompt_tokens': 4184, 'total_tokens': 4289}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None} id='run-5db9fb04-2f04-4dd1-b0d4-6f627291396c-0' usage_metadata={'input_tokens': 4184, 'output_tokens': 105, 'total_tokens': 4289}
#
#
#
# Requirement....
# Must have experience with business rules, TMCR, IETM and/or CSDB
#
# Validation Summary ... content="Based on the analysis of the subquestion and answer pairs provided, the candidate's resume shows varying levels of similarity to the job requirements of having experience with business rules, TMCR, IETM, and/or CSDB. The similarity percentages range from 0% to 90%, with some recommendations for improvement in highlighting relevant experience or skills in these areas. Overall, the candidate may need to make adjustments to their resume to better align with the specific technical keywords and requirements mentioned in the job description." response_metadata={'token_usage': {'completion_tokens': 100, 'prompt_tokens': 3719, 'total_tokens': 3819}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None} id='run-b64bf614-8cf8-46ef-bbef-7c509c2ae635-0' usage_metadata={'input_tokens': 3719, 'output_tokens': 100, 'total_tokens': 3819}
#
#
#
# Requirement....
# Must have experience with US military program office is desired
#
# Validation Summary ... content="Based on the subquestion and answer pairs provided, the candidate's resume shows a low similarity percentage of around 10-20% in meeting the requirement of having experience with US military program offices. The resume primarily focuses on program management, product development, and technical project management in various industries, but does not specifically mention experience with US military program offices. To increase the similarity percentage and better align with this requirement, the candidate should highlight any relevant experience or projects related to working with government or military contracts, programs, or agencies in their resume." response_metadata={'token_usage': {'completion_tokens': 108, 'prompt_tokens': 1866, 'total_tokens': 1974}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None} id='run-260c1089-645e-405f-802d-207592ed17f2-0' usage_metadata={'input_tokens': 1866, 'output_tokens': 108, 'total_tokens': 1974}
#
#
#
# Requirement....
# Must have Government proposal experience is desired
#
# Validation Summary ... content="Based on the subquestion and answer pairs provided, the candidate's resume does not directly mention any experience with government proposals, resulting in a low similarity percentage of around 0%. To increase the alignment with this requirement, the candidate could highlight any relevant experience or skills related to government proposal writing, procurement processes, or working with government agencies. By showcasing specific projects or roles where they have successfully worked on government proposals, obtaining relevant certifications or training in government procurement, and incorporating keywords from the job requirement, the candidate can enhance their profile and increase their chances of meeting the desired criteria." response_metadata={'token_usage': {'completion_tokens': 115, 'prompt_tokens': 1414, 'total_tokens': 1529}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None} id='run-d2d7671d-6d09-4c55-bf38-ce7ab6c4e393-0' usage_metadata={'input_tokens': 1414, 'output_tokens': 115, 'total_tokens': 1529}
#
#
#
# Requirement....
# Must be able to obtain and hold a US secret security clearance
#
# Validation Summary ... content="Based on the subquestion and answer pairs provided, the candidate's resume shows a low similarity percentage of around 10-20% to the job requirement of being able to obtain and hold a US secret security clearance. The resume does not directly mention any experience or qualifications related to security clearances, which is a key requirement for the job. \n\nTo improve the alignment and increase the likelihood of meeting this requirement, the candidate should consider highlighting any relevant security clearance or related experience, emphasizing transferable skills related to security protocols, information security, or cybersecurity, and showcasing any certifications or training related to security clearances on their resume. By doing so, the candidate can enhance their qualifications and increase the similarity percentage with the job requirement." response_metadata={'token_usage': {'completion_tokens': 145, 'prompt_tokens': 1679, 'total_tokens': 1824}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None} id='run-7c1face9-a75a-46d9-a4b4-c82d59e57d84-0' usage_metadata={'input_tokens': 1679, 'output_tokens': 145, 'total_tokens': 1824}
#
#
#
# Requirement....
# Have Experience manage all phases of the program from conceptualization through completion, including acquisition, planning, and managing technical performance to ensure quality, business, and financial objectives are attained.
#
# Validation Summary ... content="Based on the subquestion and answer pairs provided, the candidate's resume demonstrates a high level of similarity to the job requirements of managing all phases of a program from conceptualization through completion, including acquisition, planning, and managing technical performance to ensure quality, business, and financial objectives are met. The similarity percentage ranges from 80% to 90% across the responses, indicating that the candidate's experience and skills align well with the specific requirements of the role. \n\nThe candidate has extensive experience in program management, software development, and technical performance management, showcasing a strong background in managing end-to-end product development processes, working with cross-functional teams, and utilizing various methodologies such as Waterfall, Agile, and TDD/SDLC. Additionally, the candidate possesses technical knowledge in areas such as software development, system integration, artificial intelligence, and regulatory standards.\n\nOverall, the candidate's resume aligns well with the job requirements, demonstrating a high level of similarity and indicating that they are well-suited for the position. Further assessment through interviews and discussions is recommended to ensure a good match for the role." response_metadata={'token_usage': {'completion_tokens': 220, 'prompt_tokens': 2512, 'total_tokens': 2732}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None} id='run-7676d764-ab8c-4acc-a21e-162017dac8a7-0' usage_metadata={'input_tokens': 2512, 'output_tokens': 220, 'total_tokens': 2732}
#
#
#
# Requirement....
# Participate with engineering to establish design concepts, criteria, and engineering efforts for product research, development, testing, and integration.
#
# Validation Summary ... content="Based on the subquestion and answer pairs provided, the candidate's resume shows a high level of similarity, ranging from 80% to 90%, with the job requirement of participating with engineering to establish design concepts, criteria, and engineering efforts for product research, development, testing, and integration. The candidate's extensive experience in program management, product development, cross-functional team collaboration, and software development align well with the requirement. Overall, the candidate's background and skills make them a strong candidate for the position, with a high likelihood of satisfying the job requirement." response_metadata={'token_usage': {'completion_tokens': 112, 'prompt_tokens': 2130, 'total_tokens': 2242}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None} id='run-f63a6fda-516c-44f6-8515-6433a8c967b8-0' usage_metadata={'input_tokens': 2130, 'output_tokens': 112, 'total_tokens': 2242}
#
#
#
# Requirement....
# Interact with internal and external representatives at various levels concerning resolution of technical and scheduling issues. Act as primary contact for Logistics/Sustainment program issues.
#
# Validation Summary ... content="Based on the subquestion and answer pairs provided, the resume of Sam C. Yang shows a high level of similarity, around 90-95%, in terms of interacting with internal and external representatives for technical and scheduling issues. However, the resume does not specifically mention experience in logistics or sustainment program issues, resulting in a lower similarity percentage of around 10%. \n\nOverall, Sam's resume aligns well with the requirement to interact with internal and external representatives for technical and scheduling issues, but may need additional highlighting of logistics and sustainment program experience to fully satisfy the job requirements." response_metadata={'token_usage': {'completion_tokens': 117, 'prompt_tokens': 2925, 'total_tokens': 3042}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None} id='run-3b74d88c-09ee-459b-807f-3d54c2b6045b-0' usage_metadata={'input_tokens': 2925, 'output_tokens': 117, 'total_tokens': 3042}
#
#
#
# Requirement....
# Influence, and coordinate the preparation of proposals, business plans, proposal work statements and specifications, operating budgets, and financial terms/conditions of contract(s). Influence contract acquisitions, negotiations, and modifications.
#
# Validation Summary ... content="Based on the subquestion and answer pairs provided, the resume of Sam C. Yang shows a high level of similarity in terms of program management, product development, and technical project management. However, there is a low similarity in specific experience related to preparing proposals, business plans, work statements, operating budgets, and financial terms/conditions of contracts. \n\nOverall, the resume aligns well with the job requirements, with a similarity percentage of around 90%. While Sam's experience in program management and technical skills are strong, it would be beneficial for him to highlight any relevant experience or skills related to proposal preparation, budgeting, and contract negotiations to further increase his alignment with the job requirements." response_metadata={'token_usage': {'completion_tokens': 138, 'prompt_tokens': 2172, 'total_tokens': 2310}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None} id='run-5d91b6d7-5db4-4ba3-beee-ad246596517b-0' usage_metadata={'input_tokens': 2172, 'output_tokens': 138, 'total_tokens': 2310}
#
#
#
# Requirement....
#
#
# Validation Summary ... content="Based on the subquestion and answer pairs provided, the candidate, Sam C. Yang, has a high level of similarity to the job requirements. The percentage match ranges from 90% to 95% across various aspects such as experience in Consumer Electronics CM/OEM/ODM/JDM end-to-end NPI/Tech PM, working with cross-functional teams, software development/PM experience, and program management skills. \n\nOverall, the candidate's resume aligns well with the job requirements, showcasing a strong fit for the position. It is recommended to further highlight specific examples of projects managed, technical skills, and achievements in each area to strengthen the match with the job requirement. Additionally, emphasizing relevant keywords and certifications could further enhance the candidate's candidacy for the role." response_metadata={'token_usage': {'completion_tokens': 154, 'prompt_tokens': 4880, 'total_tokens': 5034}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None} id='run-6c9b235f-f8b2-445a-bf27-f0b88def889b-0' usage_metadata={'input_tokens': 4880, 'output_tokens': 154, 'total_tokens': 5034}

# %%
'''requirements="""Manage all phases of the program from conceptualization through completion, including acquisition, planning, and managing technical performance to ensure quality, business, and financial objectives are attained.\n\n\n\n
Develop and coordinate logistics CDRLs.\n\n\n\n
Participate with engineering to establish design concepts, criteria, and engineering efforts for product research, development, testing, and integration.\n\n\n\n
Interact with internal and external representatives at various levels concerning resolution of technical and scheduling issues. Act as primary contact for Logistics/Sustainment program issues. \n\n\n\n
Influence, and coordinate the preparation of proposals, business plans, proposal work statements and specifications, operating budgets, and financial terms/conditions of contract(s). Influence contract acquisitions, negotiations, and modifications.\n\n\n\n
Ensure technical leadership and excellence is maintained by participating in the planning, attraction, selection, retention, and development of the required management, professional, and technical talent.\n\n\n\n
Act as the primary customer contact for Logistics/Sustainment program activities and may lead program review sessions with customers to discuss cost, schedule, and technical performance.\n\n\n\n
Manage the development of and ensure the security of proprietary technology and maintain the strict confidentiality of sensitive information.\n\n\n\n
Typically requires a Bachelors, Masters or PhD in engineering, science or a related technical field as well as five or more years of progressively complex program or logistics administration experience. May substitute equivalent experience in lieu of education.\n\n\n\n
Demonstrates technical expertise and application of logistics management principles, concepts, and practice as well as leadership skills including organizing, planning, scheduling, and coordinating workloads to meet established deadlines or milestones.\n\n\n\n
Must be able to develop solutions to problems that require coordination of technologies across program requirements.\n\n\n\n
Strong communication, leadership, presentation, and interpersonal skills are required to enable an effective interface with other departments, all levels of management, professional and support staff, customers, potential customers, and government representatives.\n\n\n\n
Customer focused, must be able to work on a self-initiated basis and in a team environment, and able to work extended hours and travel as required.\n\n\n\n
Experience with LORA, SERD, LMI and/or spare analysis\n\n\n\n
Experience with business rules, TMCR, IETM and/or CSDB\n\n\n\n
Experience with US military program office is desired\n\n\n\n
Government proposal experience is desired\n\n\n\n
Must be able to obtain and hold a US secret security clearance\n\n\n\n"""
'''
